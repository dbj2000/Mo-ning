# %% [markdown]
# # **Lab-11-3 Long sequence**
#
# 긴 문장을 입력할 때는 전체를 하나의 input으로 사용할 수 없기 때문에 특정 size로 잘라서 입력한다. sentence에 특정 size의 window를 하나씩 오른쪽으로 움직이면서 하나의 chunck를 input x로, 한 character만큼 오른쪽으로 shift한 글을 y로 반복해서 dataset을 만든다.
#
# ![](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fk.kakaocdn.net%2Fdn%2Fq1w9y%2FbtqC22mezkt%2FgvgZvh7jxe1gikWDApAN71%2Fimg.png)

# %% [markdown]
# ## **Making sequence dataset from long sentence(code)**

# %%
import torch
import torch.optim as optim
import numpy as np

# %%
# Random seed to make results deterministic and reproducible
torch.manual_seed(0)

# %%
sentence = ("if you want to build a ship, don't drum up people together to "
            "collect wood and don't assign them tasks and work, but rather"
            "teach them to long for the endless immensity of the sea.")
print(len(sentence))
# Out:
# 179

# %%
# make dictionary
char_set = list(set(sentence))
char_dic = {c:i for i, c in enumerate(char_set)}

# %%
# hyper parameters
dic_size = len(char_dic)
hidden_size = len(char_dic)
sequence_length = 10 # 임의의 숫자
learning_rate = 0.1

# %%
# data setting
x_data = []
y_data = []

for i in range(0, len(sentence) - sequence_length):
  x_str = sentence[i:i + sequence_length]
  y_str = sentence[i+1:i + sequence_length + 1]
  print(i, x_str, '->', y_str)
  x_data.append([char_dic[c] for c in x_str]) # x_str을 인덱스로 저장
  y_data.append([char_dic[c] for c in y_str]) # y_str을 인덱스로 저장

x_one_hot = [np.eye(dic_size)[x] for x in x_data]
# Out:
# 0 if you wan -> f you want
# 1 f you want ->  you want
# 2  you want  -> you want t
# 3 you want t -> ou want to
# 4 ou want to -> u want to
# 5 u want to  ->  want to b
# 6  want to b -> want to bu
# 7 want to bu -> ant to bui
# 8 ant to bui -> nt to buil
# 9 nt to buil -> t to build
# 10 t to build ->  to build
# 11  to build  -> to build a
# 12 to build a -> o build a
# 13 o build a  ->  build a s
# 14  build a s -> build a sh
# 15 build a sh -> uild a shi
# 16 uild a shi -> ild a ship
# 17 ild a ship -> ld a ship,
# 18 ld a ship, -> d a ship,
# 19 d a ship,  ->  a ship, d
# 20  a ship, d -> a ship, do
# 21 a ship, do ->  ship, don
# 22  ship, don -> ship, don'
# 23 ship, don' -> hip, don't
# 24 hip, don't -> ip, don't
# 25 ip, don't  -> p, don't d
# 26 p, don't d -> , don't dr
# 27 , don't dr ->  don't dru
# 28  don't dru -> don't drum
# 29 don't drum -> on't drum
# 30 on't drum  -> n't drum u
# 31 n't drum u -> 't drum up
# 32 't drum up -> t drum up
# 33 t drum up  ->  drum up p
# 34  drum up p -> drum up pe
# 35 drum up pe -> rum up peo
# 36 rum up peo -> um up peop
# 37 um up peop -> m up peopl
# 38 m up peopl ->  up people
# 39  up people -> up people
# 40 up people  -> p people t
# 41 p people t ->  people to
# 42  people to -> people tog
# 43 people tog -> eople toge
# 44 eople toge -> ople toget
# 45 ople toget -> ple togeth
# 46 ple togeth -> le togethe
# 47 le togethe -> e together
# 48 e together ->  together
# 49  together  -> together t
# 50 together t -> ogether to
# 51 ogether to -> gether to
# 52 gether to  -> ether to c
# 53 ether to c -> ther to co
# 54 ther to co -> her to col
# 55 her to col -> er to coll
# 56 er to coll -> r to colle
# 57 r to colle ->  to collec
# 58  to collec -> to collect
# 59 to collect -> o collect
# 60 o collect  ->  collect w
# 61  collect w -> collect wo
# 62 collect wo -> ollect woo
# 63 ollect woo -> llect wood
# 64 llect wood -> lect wood
# 65 lect wood  -> ect wood a
# 66 ect wood a -> ct wood an
# 67 ct wood an -> t wood and
# 68 t wood and ->  wood and
# 69  wood and  -> wood and d
# 70 wood and d -> ood and do
# 71 ood and do -> od and don
# 72 od and don -> d and don'
# 73 d and don' ->  and don't
# 74  and don't -> and don't
# 75 and don't  -> nd don't a
# 76 nd don't a -> d don't as
# 77 d don't as ->  don't ass
# 78  don't ass -> don't assi
# 79 don't assi -> on't assig
# 80 on't assig -> n't assign
# 81 n't assign -> 't assign
# 82 't assign  -> t assign t
# 83 t assign t ->  assign th
# 84  assign th -> assign the
# 85 assign the -> ssign them
# 86 ssign them -> sign them
# 87 sign them  -> ign them t
# 88 ign them t -> gn them ta
# 89 gn them ta -> n them tas
# 90 n them tas ->  them task
# 91  them task -> them tasks
# 92 them tasks -> hem tasks
# 93 hem tasks  -> em tasks a
# 94 em tasks a -> m tasks an
# 95 m tasks an ->  tasks and
# 96  tasks and -> tasks and
# 97 tasks and  -> asks and w
# 98 asks and w -> sks and wo
# 99 sks and wo -> ks and wor
# 100 ks and wor -> s and work
# 101 s and work ->  and work,
# 102  and work, -> and work,
# 103 and work,  -> nd work, b
# 104 nd work, b -> d work, bu
# 105 d work, bu ->  work, but
# 106  work, but -> work, but
# 107 work, but  -> ork, but r
# 108 ork, but r -> rk, but ra
# 109 rk, but ra -> k, but rat
# 110 k, but rat -> , but rath
# 111 , but rath ->  but rathe
# 112  but rathe -> but rather
# 113 but rather -> ut rathert
# 114 ut rathert -> t ratherte
# 115 t ratherte ->  rathertea
# 116  rathertea -> ratherteac
# 117 ratherteac -> atherteach
# 118 atherteach -> therteach
# 119 therteach  -> herteach t
# 120 herteach t -> erteach th
# 121 erteach th -> rteach the
# 122 rteach the -> teach them
# 123 teach them -> each them
# 124 each them  -> ach them t
# 125 ach them t -> ch them to
# 126 ch them to -> h them to
# 127 h them to  ->  them to l
# 128  them to l -> them to lo
# 129 them to lo -> hem to lon
# 130 hem to lon -> em to long
# 131 em to long -> m to long
# 132 m to long  ->  to long f
# 133  to long f -> to long fo
# 134 to long fo -> o long for
# 135 o long for ->  long for
# 136  long for  -> long for t
# 137 long for t -> ong for th
# 138 ong for th -> ng for the
# 139 ng for the -> g for the
# 140 g for the  ->  for the e
# 141  for the e -> for the en
# 142 for the en -> or the end
# 143 or the end -> r the endl
# 144 r the endl ->  the endle
# 145  the endle -> the endles
# 146 the endles -> he endless
# 147 he endless -> e endless
# 148 e endless  ->  endless i
# 149  endless i -> endless im
# 150 endless im -> ndless imm
# 151 ndless imm -> dless imme
# 152 dless imme -> less immen
# 153 less immen -> ess immens
# 154 ess immens -> ss immensi
# 155 ss immensi -> s immensit
# 156 s immensit ->  immensity
# 157  immensity -> immensity
# 158 immensity  -> mmensity o
# 159 mmensity o -> mensity of
# 160 mensity of -> ensity of
# 161 ensity of  -> nsity of t
# 162 nsity of t -> sity of th
# 163 sity of th -> ity of the
# 164 ity of the -> ty of the
# 165 ty of the  -> y of the s
# 166 y of the s ->  of the se
# 167  of the se -> of the sea
# 168 of the sea -> f the sea.

# %%
# transform as torch tensor variable
X = torch.FloatTensor(x_one_hot)
Y = torch.LongTensor(y_data)

# %% [markdown]
# 지금까지는 단순한 RNN 셀 하나만 있는 model에 대해 다루었다. 하지만 모델이 데이터에 underfitting되거나 해서 모델을 좀 더 크게 만들고 싶을 때, FC layer과 stacking RNN을 더 할 수 있다.

# %% [markdown]
# ## **Adding FC layer and stacking RNN**

# %%
# declare RNN + FC
class Net(torch.nn.Module):
  def __init__(self, input_dim, hidden_dim, layers):
    super(Net, self).__init__()
    self.rnn = torch.nn.RNN(input_dim, hidden_dim, num_layers=layers, batch_first=True)
    self.fc = torch.nn.Linear(hidden_dim, hidden_dim, bias=True)

  def forward(self, x):
    x, _status = self.rnn(x)
    x = self.fc(x)
    return x
  
net = Net(dic_size, hidden_size, 2)

# %% [markdown]
# ## **Code run through**

# %%
# loss & optimizer setting
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), learning_rate)

# %%
# start training
for i in range(1):
  optimizer.zero_grad()
  ouputs = net(X) # ouputs의 Size는 [169, 10, 25]
  loss = criterion(ouputs.view(-1, dic_size), Y.view(-1))
  loss.backward()
  optimizer.step()

  results = ouputs.argmax(dim=2) # results의 Size는 [169, 10]
  predict_str = ""
  for j, result in enumerate(results):
    print(j)
    if j==0: # 맨처음에는 result에 있는걸 전부다 받아와서 sequence length만큼의 길이의 character만든다
      predict_str += ''.join([char_set[t] for t in result])
      print(predict_str)
    else: # 그 이후부터는 맨마지막 값 빼고는 기존과 겹치는 부분이기 때문에 맨마지막만 가져와서 붙여
      predict_str += char_set[result[-1]]
      print(predict_str)
# Out:
# 0
# l you want
# 1
# l you want
# 2
# l you want t
# 3
# l you want to
# 4
# l you want to
# 5
# l you want to b
# 6
# l you want to bu
# 7
# l you want to bui
# 8
# l you want to buil
# 9
# l you want to build
# 10
# l you want to build
# 11
# l you want to build a
# 12
# l you want to build a
# 13
# l you want to build a s
# 14
# l you want to build a sh
# 15
# l you want to build a shi
# 16
# l you want to build a ship
# 17
# l you want to build a ship,
# 18
# l you want to build a ship,
# 19
# l you want to build a ship, d
# 20
# l you want to build a ship, do
# 21
# l you want to build a ship, don
# 22
# l you want to build a ship, don'
# 23
# l you want to build a ship, don't
# 24
# l you want to build a ship, don't
# 25
# l you want to build a ship, don't d
# 26
# l you want to build a ship, don't dr
# 27
# l you want to build a ship, don't dru
# 28
# l you want to build a ship, don't drum
# 29
# l you want to build a ship, don't drum
# 30
# l you want to build a ship, don't drum u
# 31
# l you want to build a ship, don't drum up
# 32
# l you want to build a ship, don't drum up
# 33
# l you want to build a ship, don't drum up p
# 34
# l you want to build a ship, don't drum up pe
# 35
# l you want to build a ship, don't drum up peo
# 36
# l you want to build a ship, don't drum up peop
# 37
# l you want to build a ship, don't drum up peopl
# 38
# l you want to build a ship, don't drum up people
# 39
# l you want to build a ship, don't drum up people
# 40
# l you want to build a ship, don't drum up people t
# 41
# l you want to build a ship, don't drum up people to
# 42
# l you want to build a ship, don't drum up people tog
# 43
# l you want to build a ship, don't drum up people toge
# 44
# l you want to build a ship, don't drum up people toget
# 45
# l you want to build a ship, don't drum up people togeth
# 46
# l you want to build a ship, don't drum up people togethe
# 47
# l you want to build a ship, don't drum up people together
# 48
# l you want to build a ship, don't drum up people together
# 49
# l you want to build a ship, don't drum up people together t
# 50
# l you want to build a ship, don't drum up people together to
# 51
# l you want to build a ship, don't drum up people together to
# 52
# l you want to build a ship, don't drum up people together to c
# 53
# l you want to build a ship, don't drum up people together to co
# 54
# l you want to build a ship, don't drum up people together to col
# 55
# l you want to build a ship, don't drum up people together to coll
# 56
# l you want to build a ship, don't drum up people together to colle
# 57
# l you want to build a ship, don't drum up people together to collec
# 58
# l you want to build a ship, don't drum up people together to collect
# 59
# l you want to build a ship, don't drum up people together to collect
# 60
# l you want to build a ship, don't drum up people together to collect w
# 61
# l you want to build a ship, don't drum up people together to collect wo
# 62
# l you want to build a ship, don't drum up people together to collect woo
# 63
# l you want to build a ship, don't drum up people together to collect wood
# 64
# l you want to build a ship, don't drum up people together to collect wood
# 65
# l you want to build a ship, don't drum up people together to collect wood a
# 66
# l you want to build a ship, don't drum up people together to collect wood an
# 67
# l you want to build a ship, don't drum up people together to collect wood and
# 68
# l you want to build a ship, don't drum up people together to collect wood and
# 69
# l you want to build a ship, don't drum up people together to collect wood and d
# 70
# l you want to build a ship, don't drum up people together to collect wood and do
# 71
# l you want to build a ship, don't drum up people together to collect wood and don
# 72
# l you want to build a ship, don't drum up people together to collect wood and don'
# 73
# l you want to build a ship, don't drum up people together to collect wood and don't
# 74
# l you want to build a ship, don't drum up people together to collect wood and don't
# 75
# l you want to build a ship, don't drum up people together to collect wood and don't a
# 76
# l you want to build a ship, don't drum up people together to collect wood and don't as
# 77
# l you want to build a ship, don't drum up people together to collect wood and don't ass
# 78
# l you want to build a ship, don't drum up people together to collect wood and don't assi
# 79
# l you want to build a ship, don't drum up people together to collect wood and don't assig
# 80
# l you want to build a ship, don't drum up people together to collect wood and don't assign
# 81
# l you want to build a ship, don't drum up people together to collect wood and don't assign
# 82
# l you want to build a ship, don't drum up people together to collect wood and don't assign t
# 83
# l you want to build a ship, don't drum up people together to collect wood and don't assign th
# 84
# l you want to build a ship, don't drum up people together to collect wood and don't assign the
# 85
# l you want to build a ship, don't drum up people together to collect wood and don't assign them
# 86
# l you want to build a ship, don't drum up people together to collect wood and don't assign them
# 87
# l you want to build a ship, don't drum up people together to collect wood and don't assign them t
# 88
# l you want to build a ship, don't drum up people together to collect wood and don't assign them ta
# 89
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tas
# 90
# l you want to build a ship, don't drum up people together to collect wood and don't assign them task
# 91
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks
# 92
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks
# 93
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks a
# 94
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks an
# 95
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and
# 96
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and
# 97
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and w
# 98
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and wo
# 99
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and wor
# 100
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work
# 101
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work,
# 102
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work,
# 103
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, b
# 104
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, bu
# 105
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but
# 106
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but
# 107
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but r
# 108
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ra
# 109
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rat
# 110
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rath
# 111
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rathe
# 112
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather
# 113
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rathert
# 114
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherte
# 115
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rathertea
# 116
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteac
# 117
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach
# 118
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach
# 119
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach t
# 120
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach th
# 121
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach the
# 122
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them
# 123
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them
# 124
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them t
# 125
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to
# 126
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to
# 127
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to l
# 128
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to lo
# 129
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to lon
# 130
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long
# 131
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long
# 132
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long f
# 133
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long fo
# 134
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for
# 135
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for
# 136
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for t
# 137
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for th
# 138
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the
# 139
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the
# 140
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the e
# 141
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the en
# 142
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the end
# 143
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endl
# 144
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endle
# 145
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endles
# 146
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless
# 147
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless
# 148
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless i
# 149
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless im
# 150
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless imm
# 151
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless imme
# 152
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless immen
# 153
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless immens
# 154
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless immensi
# 155
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless immensit
# 156
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless immensity
# 157
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless immensity
# 158
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless immensity o
# 159
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless immensity of
# 160
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless immensity of
# 161
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless immensity of t
# 162
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless immensity of th
# 163
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless immensity of the
# 164
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless immensity of the
# 165
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless immensity of the s
# 166
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless immensity of the se
# 167
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless immensity of the sea
# 168
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless immensity of the sea.

# %%
# 최종 예측값
print(predict_str)
# Out:
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but ratherteach them to long for the endless immensity of the sea.
